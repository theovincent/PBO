# %% [markdown]
# # PBO learnt on several iterations
#
# ## Define paramters

# %%
# %load_ext autoreload
# %autoreload 2

import jax

# keys
seed = 1
key = jax.random.PRNGKey(seed)
env_key, key = jax.random.split(key)
shuffle_key, q_network_key, random_weights_key, pbo_network_key, bellman_iterations_key = jax.random.split(key, 5)

# Box over states and actions
max_discrete_state = 5
n_discrete_states = 7
max_discrete_action = 5
n_discrete_actions = 7

n_weights = 500

# Q function
action_range_on_max = max_discrete_action
n_actions_on_max = 50

# PBO trainings
tolerance = 0.1
max_iterations = 10000
batch_size_samples = 20
batch_size_weights = n_weights
learning_rate = {"first": 0.001, "last": 0.00005, "duration": max_iterations}
max_bellman_iterations = 1

# Visualisation
plot_freq = 200
n_iterations = 5
sleeping_time = 0
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %% [markdown]
# ## Define environment

# %%
import numpy as np

from pbo.environment.linear_quadratic import LinearQuadraticEnv


discrete_states = np.linspace(-max_discrete_state, max_discrete_state, n_discrete_states)
state_box_half_size = max_discrete_state / n_discrete_states
discrete_states_boxes = np.linspace(
    -max_discrete_state - state_box_half_size, max_discrete_state + state_box_half_size, n_discrete_states + 1
)

discrete_actions = np.linspace(-max_discrete_action, max_discrete_action, n_discrete_actions)
action_box_half_size = max_discrete_action / n_discrete_actions
discrete_actions_boxes = np.linspace(
    -max_discrete_action - action_box_half_size, max_discrete_action + action_box_half_size, n_discrete_actions + 1
)

env = LinearQuadraticEnv(env_key, max_init_state=max_discrete_state)
# Out:
# Transition: s' = As + Ba
# Transition: s' = -0.10490131378173828s + -0.6472394466400146a
# Reward: Qs² + Ra² + 2 Ssa
# Reward: -0.21946656703948975s² + -0.19231724739074707a² + -0.11510777473449707sa

# %% [markdown]
# ## Collect samples

# %% [markdown]
# ### Samples on the mesh

# %%
import jax.numpy as jnp

from pbo.sample_collection.replay_buffer import ReplayBuffer


n_samples = n_discrete_states * n_discrete_actions
replay_buffer = ReplayBuffer()

for state in discrete_states:
    for action in discrete_actions:
        env.reset(jnp.array([state]))
        next_state, reward, _, _ = env.step(jnp.array([action]))

        replay_buffer.add(jnp.array([state]), jnp.array([action]), reward, next_state)

# %% [markdown]
# ## Visualize samples

# %%
from pbo.sample_collection.count_samples import count_samples
from pbo.utils.state_action_mesh import StateActionMesh


samples_count, n_outside_boxes = count_samples(replay_buffer, discrete_states_boxes, discrete_actions_boxes)
samples_visu_mesh = StateActionMesh(discrete_states, discrete_actions, sleeping_time=0)

samples_visu_mesh.set_values(samples_count, zeros_to_nan=True)
samples_visu_mesh.show(
    f"Samples repartition, \n{int(100 * n_outside_boxes / n_samples)}% are outside the box."
)

# %% [markdown]
# ## Optimal Q function

# %%
optimal_q = env.optimal_Q_mesh(discrete_states, discrete_actions)

q_visu_mesh = StateActionMesh(discrete_states, discrete_actions, sleeping_time)

q_visu_mesh.set_values(optimal_q)
q_visu_mesh.show("Optimal q function")

# %% [markdown]
# ## Build q network

# %%
from pbo.networks.q import TheoreticalQ


q = TheoreticalQ(
    network_key=q_network_key,
    random_weights_range=None,
    random_weights_key=random_weights_key,
    action_range_on_max=action_range_on_max,
    n_actions_on_max=n_actions_on_max,
)

# %% [markdown]
# ## Build the PBOs network and the dataloaders

# %%
from pbo.networks.pbo import LinearPBO, OptimalPBO, OptimalLinearPBO
from pbo.sample_collection.dataloader import SampleDataLoader
from pbo.weights_collection.dataloader import WeightsDataLoader


replay_buffer.cast_to_jax_array()
data_loader_samples = SampleDataLoader(replay_buffer, batch_size_samples, shuffle_key)

random_weights_qs = jnp.vstack([q.random_init_weights() for _ in range(n_weights)])
data_loader_weights = WeightsDataLoader(random_weights_qs, batch_size_weights, shuffle_key)

pbo = LinearPBO(pbo_network_key, q, learning_rate, max_bellman_iterations)
pbo_optimal = OptimalPBO(env.A[0, 0], env.B[0, 0], env.Q[0, 0], env.R[0, 0], env.S[0, 0])
pbo_optimal_linear = OptimalLinearPBO(data_loader_weights.weights, pbo_optimal(data_loader_weights.weights))

# %% [markdown]
# ## Train PBO on several iterations

# %% [markdown]
# ### Define the targets of the random init weights

# %%
full_batch = {
    "reward": replay_buffer.rewards,
    "next_state": replay_buffer.next_states,
}
target_discrete_iterated_qs = pbo.compute_target(full_batch, data_loader_weights.weights).reshape((n_weights, n_discrete_states, n_discrete_actions))

# %% [markdown]
# ### Training

# %%
discrete_iterated_qs = q.discretize(
    pbo_optimal(data_loader_weights.weights), discrete_states, discrete_actions
)
np.abs(target_discrete_iterated_qs - discrete_iterated_qs).mean()
# Out:
# 29.09434

# %%
from pbo.utils.weights_iterator import WeightsIterator
from pbo.utils.shared_axis_plot import shared_axis_plot


# For visualization
weights_iterator = WeightsIterator(
    pbo.network.apply, pbo_optimal, pbo_optimal_linear, data_loader_weights.weights, n_iterations,
    env.A[0, 0], env.B[0, 0], env.Q[0, 0], env.R[0, 0], env.S[0, 0], env.P[0, 0], 0
)
l1_losses = []

iteration = 0
l1_loss = float("inf")
bellman_iterations = jnp.arange(max_bellman_iterations + 1)

while l1_loss > tolerance and iteration < max_iterations:
    cumulative_l2_loss = 0
    
    bellman_iterations_key, key = jax.random.split(bellman_iterations_key)
    for n_bellman_iterations in jax.random.permutation(key, bellman_iterations):
        data_loader_weights.shuffle()
        for batch_weights in data_loader_weights:
            data_loader_samples.shuffle()
            for batch_samples in data_loader_samples:
                pbo.params, pbo.optimizer_state, l2_loss = pbo.learn_iterations_on_batch(pbo.params, pbo.optimizer_state, batch_samples, batch_weights, int(n_bellman_iterations))
                cumulative_l2_loss += l2_loss

    iteration += 1

    # Visualization
    if iteration % plot_freq == 0:
        discrete_iterated_qs = q.discretize(
            pbo.network.apply(pbo.params, data_loader_weights.weights), discrete_states, discrete_actions
        )        
        l1_loss = np.abs(target_discrete_iterated_qs - discrete_iterated_qs).mean()
        
        weights_iterator.iterate_on_params(pbo.params, pbo.fix_point())
        weights_iterator.show(
            f"Iterations on the initial weights[0] at training iteration: {iteration}, \nl1 loss {str(np.round(l1_loss, 2))}, tolerance: {tolerance}"
        )

        l1_losses.append(l1_loss)

shared_axis_plot(l1_losses, np.array(l1_losses) * np.nan, f"every {plot_freq} iteration", "l1 loss")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/vincent/Darmstadt/PBO/simple_pbo_lqr_several_iterations.ipynb Cell 20' in <cell line: 16>()
#      <a href='vscode-notebook-cell:/home/vincent/Darmstadt/PBO/simple_pbo_lqr_several_iterations.ipynb#ch0000019?line=19'>20</a> for n_bellman_iterations in jax.random.permutation(key, bellman_iterations):
#      <a href='vscode-notebook-cell:/home/vincent/Darmstadt/PBO/simple_pbo_lqr_several_iterations.ipynb#ch0000019?line=20'>21</a>     data_loader_weights.shuffle()
# ---> <a href='vscode-notebook-cell:/home/vincent/Darmstadt/PBO/simple_pbo_lqr_several_iterations.ipynb#ch0000019?line=21'>22</a>     for batch_weights in data_loader_weights:
#      <a href='vscode-notebook-cell:/home/vincent/Darmstadt/PBO/simple_pbo_lqr_several_iterations.ipynb#ch0000019?line=22'>23</a>         data_loader_samples.shuffle()
#      <a href='vscode-notebook-cell:/home/vincent/Darmstadt/PBO/simple_pbo_lqr_several_iterations.ipynb#ch0000019?line=23'>24</a>         for batch_samples in data_loader_samples:
#
# File ~/Darmstadt/PBO/pbo/weights_collection/dataloader.py:31, in WeightsDataLoader.__getitem__(self, idx)
#      <a href='file:///home/vincent/Darmstadt/PBO/pbo/weights_collection/dataloader.py?line=28'>29</a> start = idx * self.batch_size
#      <a href='file:///home/vincent/Darmstadt/PBO/pbo/weights_collection/dataloader.py?line=29'>30</a> end = jnp.minimum((idx + 1) * self.batch_size, self.n_weights)
# ---> <a href='file:///home/vincent/Darmstadt/PBO/pbo/weights_collection/dataloader.py?line=30'>31</a> idxs = self.indexes[start:end]
#      <a href='file:///home/vincent/Darmstadt/PBO/pbo/weights_collection/dataloader.py?line=32'>33</a> return self.jitted_getitem(idxs)
#
# File ~/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py:3544, in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py?line=3540'>3541</a>   return _getslice(arr, start, stop)
#    <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py?line=3542'>3543</a> treedef, static_idx, dynamic_idx = _split_index_for_jit(idx, arr.shape)
# -> <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py?line=3543'>3544</a> return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py?line=3544'>3545</a>                unique_indices, mode, fill_value)
#
# File ~/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py:3582, in _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, fill_value)
#    <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py?line=3578'>3579</a>   y = lax.rev(y, indexer.reversed_y_dims)
#    <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py?line=3580'>3581</a> # This adds np.newaxis/None dimensions.
# -> <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py?line=3581'>3582</a> return expand_dims(y, indexer.newaxis_dims)
#
# File ~/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py:867, in expand_dims(a, axis)
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py?line=864'>865</a> if hasattr(a, "expand_dims"):
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py?line=865'>866</a>   return a.expand_dims(axis)
# --> <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py?line=866'>867</a> return lax.expand_dims(a, axis)
#
# File ~/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/lax/lax.py:1216, in expand_dims(array, dimensions)
#    <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/lax/lax.py?line=1213'>1214</a>   result_shape.insert(i, 1)
#    <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/lax/lax.py?line=1214'>1215</a> broadcast_dims = [i for i in range(ndim_out) if i not in dims_set]
# -> <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/lax/lax.py?line=1215'>1216</a> return broadcast_in_dim(array, result_shape, broadcast_dims)
#
# File ~/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/lax/lax.py:750, in broadcast_in_dim(operand, shape, broadcast_dimensions)
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/lax/lax.py?line=747'>748</a>   dyn_shape = []
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/lax/lax.py?line=748'>749</a>   shape_ = shape  # type: ignore
# --> <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/lax/lax.py?line=749'>750</a> return broadcast_in_dim_p.bind(
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/lax/lax.py?line=750'>751</a>     operand, *dyn_shape, shape=tuple(shape_),
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/lax/lax.py?line=751'>752</a>     broadcast_dimensions=tuple(broadcast_dimensions))
#
# File ~/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/core.py:325, in Primitive.bind(self, *args, **params)
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/core.py?line=321'>322</a> def bind(self, *args, **params):
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/core.py?line=322'>323</a>   assert (not config.jax_enable_checks or
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/core.py?line=323'>324</a>           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/core.py?line=324'>325</a>   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/core.py:328, in Primitive.bind_with_trace(self, trace, args, params)
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/core.py?line=326'>327</a> def bind_with_trace(self, trace, args, params):
# --> <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/core.py?line=327'>328</a>   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/core.py?line=328'>329</a>   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/core.py:677, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/core.py?line=675'>676</a> def process_primitive(self, primitive, tracers, params):
# --> <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/core.py?line=676'>677</a>   return primitive.impl(*tracers, **params)
#
# File ~/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py:100, in apply_primitive(prim, *args, **params)
#      <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=96'>97</a> """Impl rule that compiles and runs a single primitive 'prim' using XLA."""
#      <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=97'>98</a> compiled_fun = xla_primitive_callable(prim, *unsafe_map(arg_spec, args),
#      <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=98'>99</a>                                       **params)
# --> <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=99'>100</a> return compiled_fun(*args)
#
# File ~/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py:151, in xla_primitive_callable.<locals>.<lambda>(*args, **kw)
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=147'>148</a> compiled = _xla_callable_uncached(lu.wrap_init(prim_fun), device, None,
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=148'>149</a>                                   prim.name, donated_invars, False, *arg_specs)
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=149'>150</a> if not prim.multiple_results:
# --> <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=150'>151</a>   return lambda *args, **kw: compiled(*args, **kw)[0]
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=151'>152</a> else:
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=152'>153</a>   return compiled
#
# File ~/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py:652, in _execute_trivial(jaxpr, device, consts, avals, handlers, _, kept_var_idx, *args)
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=649'>650</a> pruned_args = (x for i, x in enumerate(args) if i in kept_var_idx)
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=650'>651</a> map(env.setdefault, jaxpr.invars, pruned_args)
# --> <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=651'>652</a> map(env.setdefault, jaxpr.constvars, consts)
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=652'>653</a> outs = [xla.canonicalize_dtype(v.val) if type(v) is core.Literal else env[v]
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=653'>654</a>         for v in jaxpr.outvars]
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=654'>655</a> return [_copy_device_array_to_device(x, device) if device_array.type_is_device_array(x)
#     <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/dispatch.py?line=655'>656</a>         else h(*device_put(x, device)) for h, x in zip(handlers, outs)]
#
# File ~/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/util.py:42, in safe_map(f, *args)
#      <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/util.py?line=38'>39</a>     assert len(arg) == n, 'length mismatch: {}'.format(list(map(len, args)))
#      <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/util.py?line=39'>40</a>   return list(zip(*args))
# ---> <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/util.py?line=41'>42</a> def safe_map(f, *args):
#      <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/util.py?line=42'>43</a>   args = list(map(list, args))
#      <a href='file:///home/vincent/Darmstadt/PBO/env/lib/python3.8/site-packages/jax/_src/util.py?line=43'>44</a>   n = len(args[0])
#
# KeyboardInterrupt:
