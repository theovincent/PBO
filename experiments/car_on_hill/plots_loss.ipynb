# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

experiment_name = "first_try"
max_bellman_iterations = 4
seed = 1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fqi_loss = np.load(f"figures/{experiment_name}/FQI/{max_bellman_iterations}_L_{seed}.npy")

for bellman_iteration, loss_fit in enumerate(fqi_loss):
    plt.plot(loss_fit, label=f"iteration {bellman_iteration}")

plt.legend()
_ = plt.title("FQI training loss")

# %%
pbo_linear_loss = np.load(f"figures/{experiment_name}/PBO_linear/{max_bellman_iterations}_L_{seed}.npy")

plt.plot(pbo_linear_loss.flatten())
_ = plt.title(f"PBO linear training loss with {pbo_linear_loss.shape[1]} fitting steps")

# %%
pbo_deep_loss = np.load(f"figures/{experiment_name}/PBO_deep/{max_bellman_iterations}_L_{seed}.npy")

plt.plot(pbo_deep_loss.flatten())

_ = plt.title(f"PBO deep training loss with {pbo_deep_loss.shape[1]} fitting steps")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/vincent/Darmstadt/PBO/experiments/car_on_hill/plots_loss.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/vincent/Darmstadt/PBO/experiments/car_on_hill/plots_loss.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> pbo_deep_loss = np.load(f"figures/{experiment_name}/PBO_deep/{max_bellman_iterations}_L_{seed}.npy")
#       <a href='vscode-notebook-cell:/home/vincent/Darmstadt/PBO/experiments/car_on_hill/plots_loss.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> plt.plot(pbo_deep_loss.flatten())
#       <a href='vscode-notebook-cell:/home/vincent/Darmstadt/PBO/experiments/car_on_hill/plots_loss.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> _ = plt.title(f"PBO deep training loss with {pbo_deep_loss.shape[1]} fitting steps")
#
# File ~/Darmstadt/PBO/env_gpu/lib/python3.8/site-packages/numpy/lib/npyio.py:390, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     388     own_fid = False
#     389 else:
# --> 390     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     391     own_fid = True
#     393 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figures/first_try/PBO_deep/4_L_1.npy'

# %%
ifqi_loss = np.load(f"figures/{experiment_name}/IFQI/{max_bellman_iterations}_L_{seed}.npy")

plt.plot(ifqi_loss.flatten())

_ = plt.title(f"IFQI training loss with {ifqi_loss.shape[1]} fitting steps")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/vincent/Darmstadt/PBO/experiments/car_on_hill/plots_loss.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/vincent/Darmstadt/PBO/experiments/car_on_hill/plots_loss.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> ifqi_loss = np.load(f"figures/{experiment_name}/IFQI/{max_bellman_iterations}_L_{seed}.npy")
#       <a href='vscode-notebook-cell:/home/vincent/Darmstadt/PBO/experiments/car_on_hill/plots_loss.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> plt.plot(ifqi_loss.flatten())
#       <a href='vscode-notebook-cell:/home/vincent/Darmstadt/PBO/experiments/car_on_hill/plots_loss.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> _ = plt.title(f"IFQI training loss with {ifqi_loss.shape[1]} fitting steps")
#
# File ~/Darmstadt/PBO/env_gpu/lib/python3.8/site-packages/numpy/lib/npyio.py:390, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     388     own_fid = False
#     389 else:
# --> 390     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     391     own_fid = True
#     393 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figures/first_try/IFQI/5_L_1.npy'
